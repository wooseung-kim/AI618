# %%
import json
from pathlib import Path
import numpy as np
import pandas as pd
import warnings

# %%
pred_dir = Path('./videos/video_1/keypoints_json') # directory including keypoints.json files
gt_dir   = Path('./videos/video_1/keypoints_json') # directory including keypoints.json files
thresh   = 0.2   # Threshold ratio
person_idx = 0   # Person index (0-base)

pred_files = sorted(pred_dir.glob('*.json'))
gt_files   = sorted(gt_dir.glob('*.json'))

pair_cnt = min(len(pred_files), len(gt_files))
if len(pred_files) != len(gt_files):
    warnings.warn(f'Directory sizes differ (pred {len(pred_files)}, gt {len(gt_files)}). Evaluating {pair_cnt} pairs.')

results = []

# %%
for idx in range(pair_cnt):
    pred_path = pred_files[idx]
    gt_path   = gt_files[idx]
    try:
        # --- Load keypoints ---
        with open(pred_path, 'r') as f:
            pred_data = json.load(f)
        with open(gt_path, 'r') as f:
            gt_data = json.load(f)

        pred_people = pred_data.get('people', [])
        gt_people   = gt_data.get('people', [])

        if not pred_people or not gt_people:
            raise ValueError('No people in one of the files.')

        if person_idx >= len(pred_people) or person_idx >= len(gt_people):
            raise IndexError('person_index out of range.')

        pred_arr = np.asarray(pred_people[person_idx]['pose_keypoints_2d']).reshape(-1, 3)
        gt_arr   = np.asarray(gt_people[person_idx]['pose_keypoints_2d']).reshape(-1, 3)

        kp_pred = pred_arr[:, :2]
        kp_gt   = gt_arr[:, :2]
        conf_gt = gt_arr[:, 2]

        # --- Torso length (L-Shoulder 5 ↔ R-Hip 9) ---
        torso_len = np.linalg.norm(kp_gt[5] - kp_gt[9])
        if torso_len == 0:
            raise ValueError('Zero torso length in GT.')

        valid = conf_gt > 0.05
        dists = np.linalg.norm(kp_pred[valid] - kp_gt[valid], axis=1)
        correct = dists < thresh * torso_len
        pck_val = correct.mean()

        results.append({'index': int(idx),
                        'pred_file': str(pred_path.name),
                        'gt_file':   str(gt_path.name),
                        'PCK': float(pck_val)})
    except Exception as e:
        results.append({'index': int(idx),
                        'pred_file': str(pred_path.name),
                        'gt_file':   str(gt_path.name),
                        'PCK': np.nan,
                        'error': str(e)})

# %%
valid_pck = [r["PCK"] for r in results if isinstance(r["PCK"], float) and not np.isnan(r["PCK"])]
mean_pck_list = np.mean(valid_pck) if valid_pck else float("nan")
print(f"\nMean PCK@{thresh:.1f} = {mean_pck_list*100:.2f}%")
# Out:
# Mean PCK@0.2 = 100.00%

# %%
results
# Out:
# [{'index': 0,
#   'pred_file': 'frame_000000_keypoints.json',
#   'gt_file': 'frame_000000_keypoints.json',
#   'PCK': 1.0},
#  {'index': 1,
#   'pred_file': 'frame_000001_keypoints.json',
#   'gt_file': 'frame_000001_keypoints.json',
#   'PCK': 1.0},
#  {'index': 2,
#   'pred_file': 'frame_000002_keypoints.json',
#   'gt_file': 'frame_000002_keypoints.json',
#   'PCK': 1.0},
#  {'index': 3,
#   'pred_file': 'frame_000003_keypoints.json',
#   'gt_file': 'frame_000003_keypoints.json',
#   'PCK': 1.0},
#  {'index': 4,
#   'pred_file': 'frame_000004_keypoints.json',
#   'gt_file': 'frame_000004_keypoints.json',
#   'PCK': 1.0},
#  {'index': 5,
#   'pred_file': 'frame_000005_keypoints.json',
#   'gt_file': 'frame_000005_keypoints.json',
#   'PCK': 1.0},
#  {'index': 6,
#   'pred_file': 'frame_000006_keypoints.json',
#   'gt_file': 'frame_000006_keypoints.json',
#   'PCK': 1.0},
#  {'index': 7,
#   'pred_file': 'frame_000007_keypoints.json',
#   'gt_file': 'frame_000007_keypoints.json',
#   'PCK': 1.0},
#  {'index': 8,
#   'pred_file': 'frame_000008_keypoints.json',
#   'gt_file': 'frame_000008_keypoints.json',
#   'PCK': 1.0},
#  {'index': 9,
#   'pred_file': 'frame_000009_keypoints.json',
#   'gt_file': 'frame_000009_keypoints.json',
#   'PCK': 1.0},
#  {'index': 10,
#   'pred_file': 'frame_000010_keypoints.json',
#   'gt_file': 'frame_000010_keypoints.json',
#   'PCK': 1.0},
#  {'index': 11,
#   'pred_file': 'frame_000011_keypoints.json',
#   'gt_file': 'frame_000011_keypoints.json',
#   'PCK': 1.0},
#  {'index': 12,
#   'pred_file': 'frame_000012_keypoints.json',
#   'gt_file': 'frame_000012_keypoints.json',
#   'PCK': 1.0},
#  {'index': 13,
#   'pred_file': 'frame_000013_keypoints.json',
#   'gt_file': 'frame_000013_keypoints.json',
#   'PCK': 1.0},
#  {'index': 14,
#   'pred_file': 'frame_000014_keypoints.json',
#   'gt_file': 'frame_000014_keypoints.json',
#   'PCK': 1.0},
#  {'index': 15,
#   'pred_file': 'frame_000015_keypoints.json',
#   'gt_file': 'frame_000015_keypoints.json',
#   'PCK': 1.0},
#  {'index': 16,
#   'pred_file': 'frame_000016_keypoints.json',
#   'gt_file': 'frame_000016_keypoints.json',
#   'PCK': 1.0},
#  {'index': 17,
#   'pred_file': 'frame_000017_keypoints.json',
#   'gt_file': 'frame_000017_keypoints.json',
#   'PCK': 1.0},
#  {'index': 18,
#   'pred_file': 'frame_000018_keypoints.json',
#   'gt_file': 'frame_000018_keypoints.json',
#   'PCK': 1.0},
#  {'index': 19,
#   'pred_file': 'frame_000019_keypoints.json',
#   'gt_file': 'frame_000019_keypoints.json',
#   'PCK': 1.0},
#  {'index': 20,
#   'pred_file': 'frame_000020_keypoints.json',
#   'gt_file': 'frame_000020_keypoints.json',
#   'PCK': 1.0},
#  {'index': 21,
#   'pred_file': 'frame_000021_keypoints.json',
#   'gt_file': 'frame_000021_keypoints.json',
#   'PCK': 1.0},
#  {'index': 22,
#   'pred_file': 'frame_000022_keypoints.json',
#   'gt_file': 'frame_000022_keypoints.json',
#   'PCK': 1.0},
#  {'index': 23,
#   'pred_file': 'frame_000023_keypoints.json',
#   'gt_file': 'frame_000023_keypoints.json',
#   'PCK': 1.0},
#  {'index': 24,
#   'pred_file': 'frame_000024_keypoints.json',
#   'gt_file': 'frame_000024_keypoints.json',
#   'PCK': 1.0},
#  {'index': 25,
#   'pred_file': 'frame_000025_keypoints.json',
#   'gt_file': 'frame_000025_keypoints.json',
#   'PCK': 1.0},
#  {'index': 26,
#   'pred_file': 'frame_000026_keypoints.json',
#   'gt_file': 'frame_000026_keypoints.json',
#   'PCK': 1.0},
#  {'index': 27,
#   'pred_file': 'frame_000027_keypoints.json',
#   'gt_file': 'frame_000027_keypoints.json',
#   'PCK': 1.0},
#  {'index': 28,
#   'pred_file': 'frame_000028_keypoints.json',
#   'gt_file': 'frame_000028_keypoints.json',
#   'PCK': 1.0},
#  {'index': 29,
#   'pred_file': 'frame_000029_keypoints.json',
#   'gt_file': 'frame_000029_keypoints.json',
#   'PCK': 1.0},
#  {'index': 30,
#   'pred_file': 'frame_000030_keypoints.json',
#   'gt_file': 'frame_000030_keypoints.json',
#   'PCK': 1.0},
#  {'index': 31,
#   'pred_file': 'frame_000031_keypoints.json',
#   'gt_file': 'frame_000031_keypoints.json',
#   'PCK': 1.0},
#  {'index': 32,
#   'pred_file': 'frame_000032_keypoints.json',
#   'gt_file': 'frame_000032_keypoints.json',
#   'PCK': 1.0},
#  {'index': 33,
#   'pred_file': 'frame_000033_keypoints.json',
#   'gt_file': 'frame_000033_keypoints.json',
#   'PCK': 1.0},
#  {'index': 34,
#   'pred_file': 'frame_000034_keypoints.json',
#   'gt_file': 'frame_000034_keypoints.json',
#   'PCK': 1.0},
#  {'index': 35,
#   'pred_file': 'frame_000035_keypoints.json',
#   'gt_file': 'frame_000035_keypoints.json',
#   'PCK': 1.0},
#  {'index': 36,
#   'pred_file': 'frame_000036_keypoints.json',
#   'gt_file': 'frame_000036_keypoints.json',
#   'PCK': 1.0},
#  {'index': 37,
#   'pred_file': 'frame_000037_keypoints.json',
#   'gt_file': 'frame_000037_keypoints.json',
#   'PCK': 1.0},
#  {'index': 38,
#   'pred_file': 'frame_000038_keypoints.json',
#   'gt_file': 'frame_000038_keypoints.json',
#   'PCK': 1.0},
#  {'index': 39,
#   'pred_file': 'frame_000039_keypoints.json',
#   'gt_file': 'frame_000039_keypoints.json',
#   'PCK': 1.0},
#  {'index': 40,
#   'pred_file': 'frame_000040_keypoints.json',
#   'gt_file': 'frame_000040_keypoints.json',
#   'PCK': 1.0},
#  {'index': 41,
#   'pred_file': 'frame_000041_keypoints.json',
#   'gt_file': 'frame_000041_keypoints.json',
#   'PCK': 1.0},
#  {'index': 42,
#   'pred_file': 'frame_000042_keypoints.json',
#   'gt_file': 'frame_000042_keypoints.json',
#   'PCK': 1.0},
#  {'index': 43,
#   'pred_file': 'frame_000043_keypoints.json',
#   'gt_file': 'frame_000043_keypoints.json',
#   'PCK': 1.0},
#  {'index': 44,
#   'pred_file': 'frame_000044_keypoints.json',
#   'gt_file': 'frame_000044_keypoints.json',
#   'PCK': 1.0},
#  {'index': 45,
#   'pred_file': 'frame_000045_keypoints.json',
#   'gt_file': 'frame_000045_keypoints.json',
#   'PCK': 1.0},
#  {'index': 46,
#   'pred_file': 'frame_000046_keypoints.json',
#   'gt_file': 'frame_000046_keypoints.json',
#   'PCK': 1.0},
#  {'index': 47,
#   'pred_file': 'frame_000047_keypoints.json',
#   'gt_file': 'frame_000047_keypoints.json',
#   'PCK': 1.0},
#  {'index': 48,
#   'pred_file': 'frame_000048_keypoints.json',
#   'gt_file': 'frame_000048_keypoints.json',
#   'PCK': 1.0},
#  {'index': 49,
#   'pred_file': 'frame_000049_keypoints.json',
#   'gt_file': 'frame_000049_keypoints.json',
#   'PCK': 1.0},
#  {'index': 50,
#   'pred_file': 'frame_000050_keypoints.json',
#   'gt_file': 'frame_000050_keypoints.json',
#   'PCK': 1.0},
#  {'index': 51,
#   'pred_file': 'frame_000051_keypoints.json',
#   'gt_file': 'frame_000051_keypoints.json',
#   'PCK': 1.0},
#  {'index': 52,
#   'pred_file': 'frame_000052_keypoints.json',
#   'gt_file': 'frame_000052_keypoints.json',
#   'PCK': 1.0},
#  {'index': 53,
#   'pred_file': 'frame_000053_keypoints.json',
#   'gt_file': 'frame_000053_keypoints.json',
#   'PCK': 1.0},
#  {'index': 54,
#   'pred_file': 'frame_000054_keypoints.json',
#   'gt_file': 'frame_000054_keypoints.json',
#   'PCK': 1.0},
#  {'index': 55,
#   'pred_file': 'frame_000055_keypoints.json',
#   'gt_file': 'frame_000055_keypoints.json',
#   'PCK': 1.0},
#  {'index': 56,
#   'pred_file': 'frame_000056_keypoints.json',
#   'gt_file': 'frame_000056_keypoints.json',
#   'PCK': 1.0},
#  {'index': 57,
#   'pred_file': 'frame_000057_keypoints.json',
#   'gt_file': 'frame_000057_keypoints.json',
#   'PCK': 1.0},
#  {'index': 58,
#   'pred_file': 'frame_000058_keypoints.json',
#   'gt_file': 'frame_000058_keypoints.json',
#   'PCK': 1.0},
#  {'index': 59,
#   'pred_file': 'frame_000059_keypoints.json',
#   'gt_file': 'frame_000059_keypoints.json',
#   'PCK': 1.0},
#  {'index': 60,
#   'pred_file': 'frame_000060_keypoints.json',
#   'gt_file': 'frame_000060_keypoints.json',
#   'PCK': 1.0},
#  {'index': 61,
#   'pred_file': 'frame_000061_keypoints.json',
#   'gt_file': 'frame_000061_keypoints.json',
#   'PCK': 1.0},
#  {'index': 62,
#   'pred_file': 'frame_000062_keypoints.json',
#   'gt_file': 'frame_000062_keypoints.json',
#   'PCK': 1.0},
#  {'index': 63,
#   'pred_file': 'frame_000063_keypoints.json',
#   'gt_file': 'frame_000063_keypoints.json',
#   'PCK': 1.0},
#  {'index': 64,
#   'pred_file': 'frame_000064_keypoints.json',
#   'gt_file': 'frame_000064_keypoints.json',
#   'PCK': 1.0},
#  {'index': 65,
#   'pred_file': 'frame_000065_keypoints.json',
#   'gt_file': 'frame_000065_keypoints.json',
#   'PCK': 1.0},
#  {'index': 66,
#   'pred_file': 'frame_000066_keypoints.json',
#   'gt_file': 'frame_000066_keypoints.json',
#   'PCK': 1.0},
#  {'index': 67,
#   'pred_file': 'frame_000067_keypoints.json',
#   'gt_file': 'frame_000067_keypoints.json',
#   'PCK': 1.0},
#  {'index': 68,
#   'pred_file': 'frame_000068_keypoints.json',
#   'gt_file': 'frame_000068_keypoints.json',
#   'PCK': 1.0},
#  {'index': 69,
#   'pred_file': 'frame_000069_keypoints.json',
#   'gt_file': 'frame_000069_keypoints.json',
#   'PCK': 1.0},
#  {'index': 70,
#   'pred_file': 'frame_000070_keypoints.json',
#   'gt_file': 'frame_000070_keypoints.json',
#   'PCK': 1.0},
#  {'index': 71,
#   'pred_file': 'frame_000071_keypoints.json',
#   'gt_file': 'frame_000071_keypoints.json',
#   'PCK': 1.0},
#  {'index': 72,
#   'pred_file': 'frame_000072_keypoints.json',
#   'gt_file': 'frame_000072_keypoints.json',
#   'PCK': 1.0},
#  {'index': 73,
#   'pred_file': 'frame_000073_keypoints.json',
#   'gt_file': 'frame_000073_keypoints.json',
#   'PCK': 1.0},
#  {'index': 74,
#   'pred_file': 'frame_000074_keypoints.json',
#   'gt_file': 'frame_000074_keypoints.json',
#   'PCK': 1.0},
#  {'index': 75,
#   'pred_file': 'frame_000075_keypoints.json',
#   'gt_file': 'frame_000075_keypoints.json',
#   'PCK': 1.0},
#  {'index': 76,
#   'pred_file': 'frame_000076_keypoints.json',
#   'gt_file': 'frame_000076_keypoints.json',
#   'PCK': 1.0},
#  {'index': 77,
#   'pred_file': 'frame_000077_keypoints.json',
#   'gt_file': 'frame_000077_keypoints.json',
#   'PCK': 1.0},
#  {'index': 78,
#   'pred_file': 'frame_000078_keypoints.json',
#   'gt_file': 'frame_000078_keypoints.json',
#   'PCK': 1.0},
#  {'index': 79,
#   'pred_file': 'frame_000079_keypoints.json',
#   'gt_file': 'frame_000079_keypoints.json',
#   'PCK': 1.0},
#  {'index': 80,
#   'pred_file': 'frame_000080_keypoints.json',
#   'gt_file': 'frame_000080_keypoints.json',
#   'PCK': 1.0},
#  {'index': 81,
#   'pred_file': 'frame_000081_keypoints.json',
#   'gt_file': 'frame_000081_keypoints.json',
#   'PCK': 1.0},
#  {'index': 82,
#   'pred_file': 'frame_000082_keypoints.json',
#   'gt_file': 'frame_000082_keypoints.json',
#   'PCK': 1.0},
#  {'index': 83,
#   'pred_file': 'frame_000083_keypoints.json',
#   'gt_file': 'frame_000083_keypoints.json',
#   'PCK': 1.0},
#  {'index': 84,
#   'pred_file': 'frame_000084_keypoints.json',
#   'gt_file': 'frame_000084_keypoints.json',
#   'PCK': 1.0},
#  {'index': 85,
#   'pred_file': 'frame_000085_keypoints.json',
#   'gt_file': 'frame_000085_keypoints.json',
#   'PCK': 1.0},
#  {'index': 86,
#   'pred_file': 'frame_000086_keypoints.json',
#   'gt_file': 'frame_000086_keypoints.json',
#   'PCK': 1.0},
#  {'index': 87,
#   'pred_file': 'frame_000087_keypoints.json',
#   'gt_file': 'frame_000087_keypoints.json',
#   'PCK': 1.0},
#  {'index': 88,
#   'pred_file': 'frame_000088_keypoints.json',
#   'gt_file': 'frame_000088_keypoints.json',
#   'PCK': 1.0},
#  {'index': 89,
#   'pred_file': 'frame_000089_keypoints.json',
#   'gt_file': 'frame_000089_keypoints.json',
#   'PCK': 1.0},
#  {'index': 90,
#   'pred_file': 'frame_000090_keypoints.json',
#   'gt_file': 'frame_000090_keypoints.json',
#   'PCK': 1.0},
#  {'index': 91,
#   'pred_file': 'frame_000091_keypoints.json',
#   'gt_file': 'frame_000091_keypoints.json',
#   'PCK': 1.0},
#  {'index': 92,
#   'pred_file': 'frame_000092_keypoints.json',
#   'gt_file': 'frame_000092_keypoints.json',
#   'PCK': 1.0},
#  {'index': 93,
#   'pred_file': 'frame_000093_keypoints.json',
#   'gt_file': 'frame_000093_keypoints.json',
#   'PCK': 1.0},
#  {'index': 94,
#   'pred_file': 'frame_000094_keypoints.json',
#   'gt_file': 'frame_000094_keypoints.json',
#   'PCK': 1.0},
#  {'index': 95,
#   'pred_file': 'frame_000095_keypoints.json',
#   'gt_file': 'frame_000095_keypoints.json',
#   'PCK': 1.0},
#  {'index': 96,
#   'pred_file': 'frame_000096_keypoints.json',
#   'gt_file': 'frame_000096_keypoints.json',
#   'PCK': 1.0},
#  {'index': 97,
#   'pred_file': 'frame_000097_keypoints.json',
#   'gt_file': 'frame_000097_keypoints.json',
#   'PCK': 1.0},
#  {'index': 98,
#   'pred_file': 'frame_000098_keypoints.json',
#   'gt_file': 'frame_000098_keypoints.json',
#   'PCK': 1.0},
#  {'index': 99,
#   'pred_file': 'frame_000099_keypoints.json',
#   'gt_file': 'frame_000099_keypoints.json',
#   'PCK': 1.0},
#  {'index': 100,
#   'pred_file': 'frame_000100_keypoints.json',
#   'gt_file': 'frame_000100_keypoints.json',
#   'PCK': 1.0},
#  {'index': 101,
#   'pred_file': 'frame_000101_keypoints.json',
#   'gt_file': 'frame_000101_keypoints.json',
#   'PCK': 1.0},
#  {'index': 102,
#   'pred_file': 'frame_000102_keypoints.json',
#   'gt_file': 'frame_000102_keypoints.json',
#   'PCK': 1.0},
#  {'index': 103,
#   'pred_file': 'frame_000103_keypoints.json',
#   'gt_file': 'frame_000103_keypoints.json',
#   'PCK': 1.0},
#  {'index': 104,
#   'pred_file': 'frame_000104_keypoints.json',
#   'gt_file': 'frame_000104_keypoints.json',
#   'PCK': 1.0},
#  {'index': 105,
#   'pred_file': 'frame_000105_keypoints.json',
#   'gt_file': 'frame_000105_keypoints.json',
#   'PCK': 1.0},
#  {'index': 106,
#   'pred_file': 'frame_000106_keypoints.json',
#   'gt_file': 'frame_000106_keypoints.json',
#   'PCK': 1.0},
#  {'index': 107,
#   'pred_file': 'frame_000107_keypoints.json',
#   'gt_file': 'frame_000107_keypoints.json',
#   'PCK': 1.0},
#  {'index': 108,
#   'pred_file': 'frame_000108_keypoints.json',
#   'gt_file': 'frame_000108_keypoints.json',
#   'PCK': 1.0},
#  {'index': 109,
#   'pred_file': 'frame_000109_keypoints.json',
#   'gt_file': 'frame_000109_keypoints.json',
#   'PCK': 1.0},
#  {'index': 110,
#   'pred_file': 'frame_000110_keypoints.json',
#   'gt_file': 'frame_000110_keypoints.json',
#   'PCK': 1.0},
#  {'index': 111,
#   'pred_file': 'frame_000111_keypoints.json',
#   'gt_file': 'frame_000111_keypoints.json',
#   'PCK': 1.0},
#  {'index': 112,
#   'pred_file': 'frame_000112_keypoints.json',
#   'gt_file': 'frame_000112_keypoints.json',
#   'PCK': 1.0},
#  {'index': 113,
#   'pred_file': 'frame_000113_keypoints.json',
#   'gt_file': 'frame_000113_keypoints.json',
#   'PCK': 1.0},
#  {'index': 114,
#   'pred_file': 'frame_000114_keypoints.json',
#   'gt_file': 'frame_000114_keypoints.json',
#   'PCK': 1.0},
#  {'index': 115,
#   'pred_file': 'frame_000115_keypoints.json',
#   'gt_file': 'frame_000115_keypoints.json',
#   'PCK': 1.0},
#  {'index': 116,
#   'pred_file': 'frame_000116_keypoints.json',
#   'gt_file': 'frame_000116_keypoints.json',
#   'PCK': 1.0},
#  {'index': 117,
#   'pred_file': 'frame_000117_keypoints.json',
#   'gt_file': 'frame_000117_keypoints.json',
#   'PCK': 1.0}]
